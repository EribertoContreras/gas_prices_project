# %%
# coding 
import math
from math import sqrt
import numpy as np
import seaborn as sns
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
from pydataset import data
import scipy.stats
import scipy
import os

# needed for modeling
import sklearn.preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer
from sklearn.metrics import explained_variance_score
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression, LassoLars, TweedieRegressor
from sklearn.preprocessing import PolynomialFeatures
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (16,9)
plt.rcParams["font.size"] = 20
import requests
from statsmodels.tsa.api import Holt
#importing data frame from acquire.py file
import acquire
import prepare

# %% [markdown]
# # Acquire

# %%
df = acquire.all_gas_data()
df
# Out:
#        Year    State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# 0      1995  Alabama                0.00                             0.00
# 1      1995  Alabama                0.00                             0.00
# 2      1995  Alabama                0.00                             0.00
# 3      1995  Alabama                0.00                             0.00
# 4      1995  Alabama                0.00                             0.00
# ...     ...      ...                 ...                              ...
# 73273  2020  Wyoming                5.15                             5.15
# 73274  2020  Wyoming                5.15                             5.15
# 73275  2020  Wyoming                5.15                             5.15
# 73276  2020  Wyoming                5.15                             5.15
# 73277  2020  Wyoming                5.15                             5.15
#
#        Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# 0                      4.25                               7.21
# 1                      4.25                               7.21
# 2                      4.25                               7.21
# 3                      4.25                               7.21
# 4                      4.25                               7.21
# ...                     ...                                ...
# 73273                  7.25                               7.25
# 73274                  7.25                               7.25
# 73275                  7.25                               7.25
# 73276                  7.25                               7.25
# 73277                  7.25                               7.25
#
#        Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  \
# 0                        4.25                                 7.21
# 1                        4.25                                 7.21
# 2                        4.25                                 7.21
# 3                        4.25                                 7.21
# 4                        4.25                                 7.21
# ...                       ...                                  ...
# 73273                    7.25                                 7.25
# 73274                    7.25                                 7.25
# 73275                    7.25                                 7.25
# 73276                    7.25                                 7.25
# 73277                    7.25                                 7.25
#
#        CPI.Average Department.Of.Labor.Uncleaned.Data  ...     R1     R2  \
# 0           152.40                                ...  ...  1.079  1.063
# 1           152.40                                ...  ...  1.086  1.070
# 2           152.40                                ...  ...  1.078  1.062
# 3           152.40                                ...  ...  1.083  1.068
# 4           152.40                                ...  ...  1.083  1.068
# ...            ...                                ...  ...    ...    ...
# 73273       258.66                               5.15  ...  2.120  2.022
# 73274       258.66                               5.15  ...  2.156  2.063
# 73275       258.66                               5.15  ...  2.158  2.063
# 73276       258.66                               5.15  ...  2.224  2.137
# 73277       258.66                               5.15  ...  2.243  2.158
#
#           R3     M1     M2     M3     P1     P2     P3     D1
# 0      1.167  1.170  1.159  1.298  1.272  1.250  1.386  1.104
# 1      1.169  1.177  1.164  1.300  1.279  1.256  1.387  1.102
# 2      1.169  1.168  1.155  1.299  1.271  1.249  1.385  1.100
# 3      1.165  1.177  1.165  1.296  1.277  1.256  1.378  1.095
# 4      1.162  1.176  1.163  1.291  1.275  1.255  1.370  1.090
# ...      ...    ...    ...    ...    ...    ...    ...    ...
# 73273  2.329  2.540  2.379  2.778  2.792  2.661  2.947  2.502
# 73274  2.355  2.567  2.412  2.798  2.820  2.694  2.968  2.526
# 73275  2.361  2.565  2.407  2.800  2.821  2.693  2.973  2.559
# 73276  2.410  2.618  2.466  2.843  2.871  2.749  3.015  2.619
# 73277  2.423  2.634  2.482  2.858  2.889  2.770  3.031  2.635
#
# [73278 rows x 43 columns]

# %%
df.describe()
# Out:
#                Year  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# count  73278.000000        73278.000000                     73278.000000
# mean    2007.497421            5.592745                         6.912555
# std        7.501230            2.739560                         2.945857
# min     1995.000000            0.000000                         0.000000
# 25%     2001.000000            4.300000                         6.610000
# 50%     2007.000000            5.250000                         7.740000
# 75%     2014.000000            7.250000                         8.600000
# max     2020.000000           14.000000                        14.160000
#
#        Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# count          73278.000000                       73278.000000
# mean               6.033788                           7.548762
# std                1.116701                           0.531842
# min                4.250000                           6.420000
# 25%                5.150000                           7.210000
# 50%                5.150000                           7.520000
# 75%                7.250000                           7.920000
# max                7.250000                           8.600000
#
#        Effective.Minimum.Wage  Effective.Minimum.Wage.2020.Dollars  \
# count            73278.000000                         73278.000000
# mean                 6.541330                             8.129597
# std                  1.658027                             1.095068
# min                  4.250000                             6.420000
# 25%                  5.150000                             7.400000
# 50%                  6.600000                             7.920000
# 75%                  7.250000                             8.600000
# max                 14.000000                            14.160000
#
#         CPI.Average  Department.Of.Labor.Cleaned.Low.Value  \
# count  73278.000000                           73278.000000
# mean     206.355569                               5.592745
# std       32.901687                               2.739560
# min      152.400000                               0.000000
# 25%      177.100000                               4.300000
# 50%      207.342000                               5.250000
# 75%      236.736000                               7.250000
# max      258.660000                              14.000000
#
#        Department.Of.Labor.Cleaned.Low.Value.2020.Dollars  ...            R1  \
# count                                        73069.000000  ...  73278.000000
# mean                                             6.932327  ...      2.224849
# std                                              2.926744  ...      0.851061
# min                                              0.000000  ...      0.907000
# 25%                                              6.610000  ...      1.420000
# 50%                                              7.740000  ...      2.236000
# 75%                                              8.600000  ...      2.831000
# max                                             14.160000  ...      4.114000
#
#                  R2            R3            M1            M2            M3  \
# count  73278.000000  73278.000000  73278.000000  73278.000000  73278.000000
# mean       2.178319      2.328543      2.381831      2.320258      2.507575
# std        0.836465      0.877641      0.882893      0.859371      0.909548
# min        0.885000      0.974000      1.008000      0.979000      1.112000
# 25%        1.388000      1.489000      1.516000      1.477000      1.612000
# 50%        2.175000      2.365000      2.479000      2.404000      2.622000
# 75%        2.767000      2.979000      3.034000      2.931000      3.207000
# max        4.054000      4.247000      4.229000      4.153000      4.387000
#
#                  P1            P2            P3            D1
# count  73278.000000  73278.000000  73278.000000  73278.000000
# mean       2.518497      2.470986      2.607724      2.403887
# std        0.911727      0.895228      0.926186      0.999643
# min        1.100000      1.074000      1.191000      0.953000
# 25%        1.606000      1.570000      1.693000      1.417000
# 50%        2.686000      2.635000      2.762000      2.476000
# 75%        3.209000      3.128000      3.318000      3.070000
# max        4.344000      4.283000      4.459000      4.764000
#
# [8 rows x 27 columns]

# %% [markdown]
# # Prepare

# %%
df = prepare.prep_gas_data(df)
df
# Out:
#             Year    State  State.Minimum.Wage MeanAnnualInflation  \
# Date
# 1995-01-02  1995   Alaska                4.75               2.80%
# 1995-01-09  1995   Alaska                4.75               2.80%
# 1995-01-16  1995   Alaska                4.75               2.80%
# 1995-01-23  1995   Alaska                4.75               2.80%
# 1995-01-30  1995   Alaska                4.75               2.80%
# ...          ...      ...                 ...                 ...
# 2020-11-30  2020  Wyoming                5.15               1.20%
# 2020-12-07  2020  Wyoming                5.15               1.20%
# 2020-12-14  2020  Wyoming                5.15               1.20%
# 2020-12-21  2020  Wyoming                5.15               1.20%
# 2020-12-28  2020  Wyoming                5.15               1.20%
#
#            UnemploymentRateDecember GDP_AnnualGrowth   PresParty    SenParty  \
# Date
# 1995-01-02                    5.60%            2.70%    Democrat  Republican
# 1995-01-09                    5.60%            2.70%    Democrat  Republican
# 1995-01-16                    5.60%            2.70%    Democrat  Republican
# 1995-01-23                    5.60%            2.70%    Democrat  Republican
# 1995-01-30                    5.60%            2.70%    Democrat  Republican
# ...                             ...              ...         ...         ...
# 2020-11-30                    6.70%           -3.40%  Republican  Republican
# 2020-12-07                    6.70%           -3.40%  Republican  Republican
# 2020-12-14                    6.70%           -3.40%  Republican  Republican
# 2020-12-21                    6.70%           -3.40%  Republican  Republican
# 2020-12-28                    6.70%           -3.40%  Republican  Republican
#
#             HouseParty  YearsSinceLastChange  gasoline  diesel  state_wage  \
# Date
# 1995-01-02  Republican                     4     1.127   1.104        4.75
# 1995-01-09  Republican                     4     1.134   1.102        4.75
# 1995-01-16  Republican                     4     1.126   1.100        4.75
# 1995-01-23  Republican                     4     1.132   1.095        4.75
# 1995-01-30  Republican                     4     1.131   1.090        4.75
# ...                ...                   ...       ...     ...         ...
# 2020-11-30    Democrat                    11     2.211   2.502        5.15
# 2020-12-07    Democrat                    11     2.246   2.526        5.15
# 2020-12-14    Democrat                    11     2.247   2.559        5.15
# 2020-12-21    Democrat                    11     2.311   2.619        5.15
# 2020-12-28    Democrat                    11     2.330   2.635        5.15
#
#             fed_wage   month  gas_fed_min_dif  gas_state_min_dif  \
# Date
# 1995-01-02      4.25  01-Jan         0.265176           0.237263
# 1995-01-09      4.25  01-Jan         0.266824           0.238737
# 1995-01-16      4.25  01-Jan         0.264941           0.237053
# 1995-01-23      4.25  01-Jan         0.266353           0.238316
# 1995-01-30      4.25  01-Jan         0.266118           0.238105
# ...              ...     ...              ...                ...
# 2020-11-30      7.25  11-Nov         0.304966           0.429320
# 2020-12-07      7.25  12-Dec         0.309793           0.436117
# 2020-12-14      7.25  12-Dec         0.309931           0.436311
# 2020-12-21      7.25  12-Dec         0.318759           0.448738
# 2020-12-28      7.25  12-Dec         0.321379           0.452427
#
#             diesel_fed_min_dif  diesel_state_min_dif
# Date
# 1995-01-02            0.259765              0.232421
# 1995-01-09            0.259294              0.232000
# 1995-01-16            0.258824              0.231579
# 1995-01-23            0.257647              0.230526
# 1995-01-30            0.256471              0.229474
# ...                        ...                   ...
# 2020-11-30            0.345103              0.485825
# 2020-12-07            0.348414              0.490485
# 2020-12-14            0.352966              0.496893
# 2020-12-21            0.361241              0.508544
# 2020-12-28            0.363448              0.511650
#
# [55361 rows x 19 columns]

# %%
df = df.drop(columns= ['HouseParty','SenParty','PresParty','diesel_fed_min_dif','YearsSinceLastChange',
                       'State','gas_state_min_dif','diesel_state_min_dif','diesel','state_wage',
                      'MeanAnnualInflation','UnemploymentRateDecember','GDP_AnnualGrowth'])

# %%
df
# Out:
#             Year  State.Minimum.Wage  gasoline  fed_wage   month  \
# Date
# 1995-01-02  1995                4.75     1.127      4.25  01-Jan
# 1995-01-09  1995                4.75     1.134      4.25  01-Jan
# 1995-01-16  1995                4.75     1.126      4.25  01-Jan
# 1995-01-23  1995                4.75     1.132      4.25  01-Jan
# 1995-01-30  1995                4.75     1.131      4.25  01-Jan
# ...          ...                 ...       ...       ...     ...
# 2020-11-30  2020                5.15     2.211      7.25  11-Nov
# 2020-12-07  2020                5.15     2.246      7.25  12-Dec
# 2020-12-14  2020                5.15     2.247      7.25  12-Dec
# 2020-12-21  2020                5.15     2.311      7.25  12-Dec
# 2020-12-28  2020                5.15     2.330      7.25  12-Dec
#
#             gas_fed_min_dif
# Date
# 1995-01-02         0.265176
# 1995-01-09         0.266824
# 1995-01-16         0.264941
# 1995-01-23         0.266353
# 1995-01-30         0.266118
# ...                     ...
# 2020-11-30         0.304966
# 2020-12-07         0.309793
# 2020-12-14         0.309931
# 2020-12-21         0.318759
# 2020-12-28         0.321379
#
# [55361 rows x 6 columns]

# %%
df = df.drop(columns= ['Year','State.Minimum.Wage'])

# %%
df_resampled = df.resample('W')[['gasoline','gas_fed_min_dif']].sum()
df_resampled.head()
# Out:
#             gasoline  gas_fed_min_dif
# Date
# 1995-01-08     7.889         1.856235
# 1995-01-15     7.938         1.867765
# 1995-01-22     7.882         1.854588
# 1995-01-29     7.924         1.864471
# 1995-02-05     7.917         1.862824

# %%
df_resampled.shape
# Out:
# (1357, 2)

# %%
train_size = int(len(df) * .5)
validate_size = int(len(df) * .3)
test_size = int(round(df_resampled.shape[0] * 0.2))
len(df_resampled) == train_size + validate_size + test_size
validate_end_index = train_size + validate_size

# split into train, validation, test
train = df_resampled[:train_size]
validate = df_resampled[train_size:validate_end_index]
test = df_resampled[validate_end_index:]

# %% [markdown]
# ***

# %%
train.shape[0], validate.shape[0], test.shape[0]
# Out:
# (1357, 0, 0)

# %% [markdown]
# ### Verify Splits
#
# Does the length of each df equate to the length of the original df?

# %%
# is len of train + validate + test == lenght of entire dataframe. 
len(train) + len(validate) + len(test) == len(df_resampled)
# Out:
# True

# %%
#Does the first row of original df equate to the first row of train?
print(df_resampled.head(1) == train.head(1))
# Out:
#             gasoline  gas_fed_min_dif
# Date
# 1995-01-08      True             True

# %%
pd.concat([train.tail(1), validate.head(1)])
# Out:
#             gasoline  gas_fed_min_dif
# Date
# 2021-01-03    111.84        15.426207

# %%
pd.concat([validate.tail(1), test.head(1)])
# Out:
# Empty DataFrame
# Columns: [gasoline, gas_fed_min_dif]
# Index: []

# %%
train.columns
# Out:
# Index(['gasoline', 'gas_fed_min_dif'], dtype='object')

# %%
for col in train.columns:
    plt.figure(figsize=(14,8))
    plt.plot(train[col])
    plt.plot(validate[col])
    plt.plot(test[col])
    plt.ylabel(col)
    plt.title(col)
    plt.show()

# %%
def evaluate(target_var):
    '''
    This function will take the actual values of the target_var from validate, 
    and the predicted values stored in yhat_df, 
    and compute the rmse, rounding to 0 decimal places. 
    it will return the rmse. 
    '''
    rmse = round(sqrt(mean_squared_error(validate[target_var], yhat_df[target_var])), 0)
    return rmse

# %%
def plot_and_eval(target_var):
    '''
    This function takes in the target var name (string), and returns a plot
    of the values of train for that variable, validate, and the predicted values from yhat_df. 
    it will als lable the rmse. 
    '''
    plt.figure(figsize = (12,4))
    plt.plot(train[target_var], label='Train', linewidth=1)
    plt.plot(validate[target_var], label='Validate', linewidth=1)
    plt.plot(yhat_df[target_var])
    plt.title(target_var)
    rmse = evaluate(target_var)
    print(target_var, '-- RMSE: {:.0f}'.format(rmse))
    plt.show()

# %%
# create an empty dataframe
eval_df = pd.DataFrame(columns=['model_type', 'target_var', 'rmse'])
eval_df
# Out:
# Empty DataFrame
# Columns: [model_type, target_var, rmse]
# Index: []

# %%
# function to store the rmse so that we can compare
def append_eval_df(model_type, target_var):
    '''
    this function takes in as arguments the type of model run, and the name of the target variable. 
    It returns the eval_df with the rmse appended to it for that model and target_var. 
    '''
    rmse = evaluate(target_var)
    d = {'model_type': [model_type], 'target_var': [target_var],
        'rmse': [rmse]}
    d = pd.DataFrame(d)
    return eval_df.append(d, ignore_index = True)

# %%
eval_df
# Out:
# Empty DataFrame
# Columns: [model_type, target_var, rmse]
# Index: []

# %% [markdown]
# ### Forecast
# Forecasting is another word for predicting time series data.
#
# - Last Observed Value: The future will look like the now
# - Simple Average: The future will look, on average, like history.
# - Moving Average: The future will look, on average, like recent history.
# - Holt's Linear Trend
# - Previous Cycle
# ### Last observed value
# The simplest method for forecasting is to predict all future values to be the last observed value.
#
# ### Make Predictions
#
# gasoline prices

# %%
train['gasoline'][-1:][0]
# Out:
# 111.84

# %%
# take the last item of sales total and assign to variable
last_gas_price = train['gasoline'][-1:][0]
last_gas_price
# Out:
# 111.84

# %% [markdown]
# ### gas_fed_min_dif

# %%
# take the last item of quantity and assign to variable
last_gas_fed_min_dif = round(train['gas_fed_min_dif'][-1:][0],2)
last_gas_fed_min_dif
# Out:
# 15.43

# %%
yhat_df = pd.DataFrame(
    {'gasoline': [last_gas_price],
     'gas_fed_min_dif': [last_gas_fed_min_dif]},
    index=validate.index)

yhat_df.head()
# Out:
# Empty DataFrame
# Columns: [gasoline, gas_fed_min_dif]
# Index: []

# %%
yhat_df.describe()
# Out:
#        gasoline  gas_fed_min_dif
# count       0.0              0.0
# mean        NaN              NaN
# std         NaN              NaN
# min         NaN              NaN
# 25%         NaN              NaN
# 50%         NaN              NaN
# 75%         NaN              NaN
# max         NaN              NaN

# %% [markdown]
# ## Simple Average
# Take the simple average of historical values and use that value to predict future values.
#
# This is a good option for an initial baseline. Every future datapoint (those in 'test') will be assigned the same value, and that value will be the overall mean of the values in train.
#
# Make Predictions
#
# gasoline: establishing the value of the prediction we will make

# %%
# compute simple average
avg_gas = round(train['gasoline'].mean(), 2)
avg_gas
# Out:
# 98.75

# %%
avg_dif = round(train['gas_fed_min_dif'].mean(), 2)
avg_dif
# Out:
# 15.65

# %%
def make_predictions(gas=None, dif=None):
    yhat_df = pd.DataFrame({'gasoline': [gas],
                           'gas_fed_min_dif': [dif]},
                          index=validate.index)
    return yhat_df

# %%
yhat_df = make_predictions(avg_gas, avg_dif)

# %%
yhat_df.head()
# Out:
# Empty DataFrame
# Columns: [gasoline, gas_fed_min_dif]
# Index: []

# %%
yhat_df.describe()
# Out:
#        gasoline  gas_fed_min_dif
# count       0.0              0.0
# mean        NaN              NaN
# std         NaN              NaN
# min         NaN              NaN
# 25%         NaN              NaN
# 50%         NaN              NaN
# 75%         NaN              NaN
# max         NaN              NaN

# %% [markdown]
# ### Moving Average
# In this example, we will use a 30-day moving average to forecast. In other words, the average over the last 30-days will be used as the forecasted value.

# %%
# demonstrate that the mean of the first 30 days 
# is equal to rolling(30) on day 30

print(train['gasoline'].rolling(30).mean())
# Out:
# Date
# 1995-01-08         NaN
# 1995-01-15         NaN
# 1995-01-22         NaN
# 1995-01-29         NaN
# 1995-02-05         NaN
#                 ...
# 2020-12-06    106.1472
# 2020-12-13    106.6352
# 2020-12-20    107.0800
# 2020-12-27    107.4992
# 2021-01-03    107.9248
# Freq: W-SUN, Name: gasoline, Length: 1357, dtype: float64

# %%
period=30
train['gasoline'].rolling(period).mean()[-1]
# Out:
# 107.9248

# %%
period = 30 

# take 30 day rolling average, then take the last element and that will the one that propogates 
# forward as our prediction. 
rolling_gas = round(train['gasoline'].rolling(period).mean()[-1], 2)
rolling_dif = round(train['gas_fed_min_dif'].rolling(period).mean()[-1], 2)
print(rolling_gas, rolling_dif)
# Out:
# 107.92 14.89

# %%
yhat_df = make_predictions(rolling_gas, rolling_dif)
yhat_df.head()
# Out:
# Empty DataFrame
# Columns: [gasoline, gas_fed_min_dif]
# Index: []

# %%
for col in train.columns:
    plot_and_eval(col)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/dc/8rtfvpyj2mb6mqbnfkf5dl400000gn/T/ipykernel_23768/2290735789.py in <module>
#       1 for col in train.columns:
# ----> 2     plot_and_eval(col)
#
# /var/folders/dc/8rtfvpyj2mb6mqbnfkf5dl400000gn/T/ipykernel_23768/3259883104.py in plot_and_eval(target_var)
#      10     plt.plot(yhat_df[target_var])
#      11     plt.title(target_var)
# ---> 12     rmse = evaluate(target_var)
#      13     print(target_var, '-- RMSE: {:.0f}'.format(rmse))
#      14     plt.show()
#
# /var/folders/dc/8rtfvpyj2mb6mqbnfkf5dl400000gn/T/ipykernel_23768/653392329.py in evaluate(target_var)
#       6     it will return the rmse.
#       7     '''
# ----> 8     rmse = round(sqrt(mean_squared_error(validate[target_var], yhat_df[target_var])), 0)
#       9     return rmse
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_regression.py in mean_squared_error(y_true, y_pred, sample_weight, multioutput, squared)
#     333     0.825...
#     334     """
# --> 335     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#     336         y_true, y_pred, multioutput)
#     337     check_consistent_length(y_true, y_pred, sample_weight)
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/metrics/_regression.py in _check_reg_targets(y_true, y_pred, multioutput, dtype)
#      87     """
#      88     check_consistent_length(y_true, y_pred)
# ---> 89     y_true = check_array(y_true, ensure_2d=False, dtype=dtype)
#      90     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#      91
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# /usr/local/anaconda3/lib/python3.9/site-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     724         n_samples = _num_samples(array)
#     725         if n_samples < ensure_min_samples:
# --> 726             raise ValueError("Found array with %d sample(s) (shape=%s) while a"
#     727                              " minimum of %d is required%s."
#     728                              % (n_samples, array.shape, ensure_min_samples,
#
# ValueError: Found array with 0 sample(s) (shape=(0,)) while a minimum of 1 is required.

# %%
import statsmodels.api as sm

# %%
print(col, '\n')
sm.tsa.seasonal_decompose(train[col].resample('W').mean()).plot()
plt.show()
# Out:
# gasoline

# %%
for col in train.columns:
    print(col,'\n')
    sm.tsa.seasonal_decompose(train[col].resample('W').mean()).plot()
# Out:
# gasoline
#
# gas_fed_min_dif

# %%
train.columns
# Out:
# Index(['gasoline', 'gas_fed_min_dif'], dtype='object')

# %%
col = 'gasoline' 
# create our Holt's Object
model = Holt(train[col], exponential=False, damped=True)

# %%
# fit the holt's object
model = model.fit(optimized=True)

# %%
yhat_items = model.predict(start = validate.index[0],
                              end = validate.index[-1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/folders/dc/8rtfvpyj2mb6mqbnfkf5dl400000gn/T/ipykernel_23768/2339898098.py in <module>
# ----> 1 yhat_items = model.predict(start = validate.index[0],
#       2                               end = validate.index[-1])
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/extension.py in __getitem__(self, key)
#     277
#     278     def __getitem__(self, key):
# --> 279         result = self._data[key]
#     280         if isinstance(result, type(self._data)):
#     281             if result.ndim == 1:
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/datetimelike.py in __getitem__(self, key)
#     320         only handle list-likes, slices, and integer scalars
#     321         """
# --> 322         result = super().__getitem__(key)
#     323         if lib.is_scalar(result):
#     324             return result
#
# /usr/local/anaconda3/lib/python3.9/site-packages/pandas/core/arrays/_mixins.py in __getitem__(self, key)
#     192         if lib.is_integer(key):
#     193             # fast-path
# --> 194             result = self._ndarray[key]
#     195             if self.ndim == 1:
#     196                 return self._box_func(result)
#
# IndexError: index 0 is out of bounds for axis 0 with size 0
